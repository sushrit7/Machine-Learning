# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Data

# %%
train=pd.read_csv('F:\\Analytics Vidhya\\BigMart\\Data\\train_v9rqX0R.csv')
test=pd.read_csv('F:\\Analytics Vidhya\\BigMart\\Data\\test_AbJTz2l.csv')

# %%
train.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
train.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
train.shape
# Out:
# (8523, 12)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Target Variable

# %%
plt.subplot(121)
sns.distplot(train['Item_Outlet_Sales'])
plt.subplot(122)
train['Item_Outlet_Sales'].plot.box(figsize=(20,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Categotrical Variables

# %%
plt.subplot(131)
train['Item_Fat_Content'].value_counts(normalize= True).plot.bar(figsize=(20,7),title='Item_Fat_Content')
plt.subplot(132)
train['Item_Type'].value_counts(normalize= True).plot.bar(title='Item_Type')
plt.subplot(133)
train['Outlet_Identifier'].value_counts(normalize= True).plot.bar(title='Outlet_Identifier')
# Out:
# <AxesSubplot:title={'center':'Outlet_Identifier'}>

# %%
plt.subplot(131)
train['Outlet_Size'].value_counts(normalize= True).plot.bar(figsize=(20,7), title='Outlet_Size')
plt.subplot(132)
train['Outlet_Location_Type'].value_counts(normalize= True).plot.bar(title='Outlet_Location_Type')
plt.subplot(133)
train['Outlet_Type'].value_counts(normalize= True).plot.bar(title='Outlet_Type')
# Out:
# <AxesSubplot:title={'center':'Outlet_Type'}>

# %%
train['Item_Fat_Content'].replace('LF', 'Low Fat', inplace = True)
train['Item_Fat_Content'].replace('low fat', 'Low Fat', inplace = True)
train['Item_Fat_Content'].replace('reg', 'Regular', inplace = True)
train['Item_Fat_Content'].value_counts(normalize= True).plot.bar(figsize=(7,3),title='Item_Fat_Content')

test['Item_Fat_Content'].replace('LF', 'Low Fat', inplace = True)
test['Item_Fat_Content'].replace('low fat', 'Low Fat', inplace = True)
test['Item_Fat_Content'].replace('reg', 'Regular', inplace = True)

# %%
plt.subplot(131)
train['Outlet_Establishment_Year'].value_counts(normalize= True).plot.bar(figsize=(20,7), title='Outlet_Establishment_Year')
# Out:
# <AxesSubplot:title={'center':'Outlet_Establishment_Year'}>

# %% [markdown]
# ## Numeric Variables

# %%
train.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
plt.subplot(121)
sns.distplot(train['Item_Weight'])
plt.subplot(122)
train['Item_Weight'].plot.box(figsize=(20,6))
# Out:
# <AxesSubplot:>

# %%
plt.subplot(121)
sns.distplot(train['Item_Visibility'])
plt.subplot(122)
train['Item_Visibility'].plot.box(figsize=(20,6))
# Out:
# <AxesSubplot:>

# %%
plt.subplot(121)
sns.distplot(train['Item_MRP'])
plt.subplot(122)
train['Item_MRP'].plot.box(figsize=(20,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bivariate Analysis

# %%
sns.heatmap(train.corr(),vmax=.8,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(25,8))
sns.violinplot(x=train['Item_Type'], y=train['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(25,8))
sns.violinplot(x=train['Item_Fat_Content'], y=train['Item_Outlet_Sales']) 
plt.show()
plt.figure(figsize=(25,8))
sns.violinplot(x=train['Outlet_Identifier'], y=train['Item_Outlet_Sales']) 
plt.show()
plt.figure(figsize=(25,8))
sns.violinplot(x=train['Outlet_Size'], y=train['Item_Outlet_Sales']) 
plt.show()
plt.figure(figsize=(25,8))
sns.violinplot(x=train['Outlet_Location_Type'], y=train['Item_Outlet_Sales']) 
plt.show()
plt.figure(figsize=(25,8))
sns.violinplot(x=train['Outlet_Type'], y=train['Item_Outlet_Sales']) 
plt.show()

# %% [markdown]
# # Missing Values

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train['Item_Weight'].fillna(train['Item_Weight'].mean(), inplace=True)
test['Item_Weight'].fillna(test['Item_Weight'].mean(), inplace=True)

# %%
train['Outlet_Size'].fillna(train['Outlet_Size'].mode()[0] , inplace=True)
test['Outlet_Size'].fillna(test['Outlet_Size'].mode()[0] , inplace=True)

# %%
plt.figure(figsize=(25,8))
sns.violinplot(x=train['Outlet_Size'], y=train['Item_Outlet_Sales']) 
plt.show()

# %%
train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
train['Item_Visibility'].replace(0,train['Item_Visibility'].mean() ,inplace=True)

# %% [markdown]
# # MODEL

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93          Low Fat         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train=train.drop('Item_Identifier',axis=1)
test=test.drop('Item_Identifier',axis=1)

X=train.drop('Item_Outlet_Sales',axis=1)
y=train['Item_Outlet_Sales']

# %%
train=pd.get_dummies(train)
X=pd.get_dummies(X)
test=pd.get_dummies(test)

# %%
from sklearn.model_selection import train_test_split
xtrain,xcv,ytrain,ycv=train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
X
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.066132  182.0950                       1998
# 4           8.930         0.066132   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# ...

# %%
predcv=model.predict(xcv)
mse=np.mean((predcv-ycv)**2)
mse
# Out:
# 1221881.4430181757

# %%
from sklearn.metrics import accuracy_score
model.score(xcv, ycv)
# Out:
# 0.5647454082282104

# %%
test.astype(float)
pred_test=model.predict(test)

# %%
test.isnull().sum()
# Out:
# Item_Weight                        0
# Item_Visibility                    0
# Item_MRP                           0
# Outlet_Establishment_Year          0
# Item_Fat_Content_Low Fat           0
# Item_Fat_Content_Regular           0
# Item_Type_Baking Goods             0
# Item_Type_Breads                   0
# Item_Type_Breakfast                0
# Item_Type_Canned                   0
# Item_Type_Dairy                    0
# Item_Type_Frozen Foods             0
# Item_Type_Fruits and Vegetables    0
# Item_Type_Hard Drinks              0
# Item_Type_Health and Hygiene       0
# Item_Type_Household                0
# Item_Type_Meat                     0
# Item_Type_Others                   0
# Item_Type_Seafood                  0
# Item_Type_Snack Foods              0
# Item_Type_Soft Drinks              0
# Item_Type_Starchy Foods            0
# Outlet_Identifier_OUT010           0
# Outlet_Identifier_OUT013           0
# Outlet_Identifier_OUT017           0
# ...

# %%
submission=pd.read_csv('F:\\Analytics Vidhya\\BigMart\\Data\\sample_submission_8RXa3c6.csv')

# %%
submission
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049               1000
# 1              FDW14            OUT017               1000
# 2              NCN55            OUT010               1000
# 3              FDQ58            OUT017               1000
# 4              FDY38            OUT027               1000
# ...              ...               ...                ...
# 5676           FDB58            OUT046               1000
# 5677           FDD47            OUT018               1000
# 5678           NCO17            OUT045               1000
# 5679           FDJ26            OUT017               1000
# 5680           FDU37            OUT045               1000
#
# [5681 rows x 3 columns]

# %%
submission['Item_Outlet_Sales']=pred_test

# %%
submission
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049        1804.405073
# 1              FDW14            OUT017        1566.357865
# 2              NCN55            OUT010        1906.549443
# 3              FDQ58            OUT017        2593.267252
# 4              FDY38            OUT027        5152.955357
# ...              ...               ...                ...
# 5676           FDB58            OUT046        2349.626417
# 5677           FDD47            OUT018        2499.290221
# 5678           NCO17            OUT045        1755.674019
# 5679           FDJ26            OUT017        3627.499996
# 5680           FDU37            OUT045        1221.512437
#
# [5681 rows x 3 columns]

# %%
pd.DataFrame(submission,columns=['Item_Identifier','Outlet_Identifier','Item_Outlet_Sales']).to_csv('F:\\Analytics Vidhya\\BigMart\\Data\\Final.csv')

# %%
final=pd.read_csv('F:\\Analytics Vidhya\\BigMart\\Data\\Final.csv')

# %%
final
# Out:
#       Unnamed: 0 Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              0           FDW58            OUT049               1000
# 1              1           FDW14            OUT017               1000
# 2              2           NCN55            OUT010               1000
# 3              3           FDQ58            OUT017               1000
# 4              4           FDY38            OUT027               1000
# ...          ...             ...               ...                ...
# 5676        5676           FDB58            OUT046               1000
# 5677        5677           FDD47            OUT018               1000
# 5678        5678           NCO17            OUT045               1000
# 5679        5679           FDJ26            OUT017               1000
# 5680        5680           FDU37            OUT045               1000
#
# [5681 rows x 4 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
model1 = RandomForestRegressor()
model1.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
predcv = model.predict(xcv)
mse = np.mean(( predcv - ycv) **2 )
mse
# Out:
# 1221881.4430181757

# %%
pred_test=model.predict(test)
len(pred_test)
# Out:
# 5681

# %%
for i in range( len( pred_test) ):
    if (pred_test[i]<0):
        pred_test[i] = pred_test[i] * (-1)
        print(i, pred_test[i])

# %%
submission['Item_Outlet_Sales']=pred_test

# %%
pd.DataFrame(submission,columns=['Item_Identifier','Outlet_Identifier','Item_Outlet_Sales']).to_csv('F:\\Analytics Vidhya\\BigMart\\Data\\Final1.csv')

# %%
final=pd.read_csv('F:\\Analytics Vidhya\\BigMart\\Data\\Final1.csv')

# %%
final
# Out:
#       Unnamed: 0 Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              0           FDW58            OUT049        1804.405073
# 1              1           FDW14            OUT017        1566.357865
# 2              2           NCN55            OUT010        1906.549443
# 3              3           FDQ58            OUT017        2593.267252
# 4              4           FDY38            OUT027        5152.955357
# ...          ...             ...               ...                ...
# 5676        5676           FDB58            OUT046        2349.626417
# 5677        5677           FDD47            OUT018        2499.290221
# 5678        5678           NCO17            OUT045        1755.674019
# 5679        5679           FDJ26            OUT017        3627.499996
# 5680        5680           FDU37            OUT045        1221.512437
#
# [5681 rows x 4 columns]
